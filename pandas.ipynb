# %%
import pandas as pd
import numpy as np
a = pd.Series([10,20,30,40,50])

# %%
print(a)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s = pd.Series([1,3,4,5,6,8,9,3,5,4])
s.describe()
# Out:
# count    10.000000
# mean      4.800000
# std       2.394438
# min       1.000000
# 25%       3.250000
# 50%       4.500000
# 75%       5.750000
# max       9.000000
# dtype: float64

# %%
s.mean()
# Out:
# 4.8

# %%
s.std()
# Out:
# 2.3944379994757297

# %%
print(s.min())
print(s.max())
# Out:
# 1
# 9

# %%
doubled = s.map(lambda x:x * 2)
doubled
# Out:
# 0     2
# 1     6
# 2     8
# 3    10
# 4    12
# 5    16
# 6    18
# 7     6
# 8    10
# 9     8
# dtype: int64

# %%
sqrt=s.apply(lambda x:x**0.5)
sqrt
# Out:
# 0    1.000000
# 1    1.732051
# 2    2.000000
# 3    2.236068
# 4    2.449490
# 5    2.828427
# 6    3.000000
# 7    1.732051
# 8    2.236068
# 9    2.000000
# dtype: float64

# %%
s.sort_values()
# Out:
# 0    1
# 1    3
# 7    3
# 2    4
# 9    4
# 3    5
# 8    5
# 4    6
# 5    8
# 6    9
# dtype: int64

# %%
dropped=s.drop(5)
dropped
# Out:
# 0    1
# 1    3
# 2    4
# 3    5
# 4    6
# 6    9
# 7    3
# 8    5
# 9    4
# dtype: int64

# %%
p=pd.Series([2,4,67,None,54,76,6])
p.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# dtype: bool

# %%
p.notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5     True
# 6     True
# dtype: bool

# %%
p=pd.Series([3,5,7,np.nan,4,None])
p.fillna
# Out:
# <bound method NDFrame.fillna of 0    3.0
# 1    5.0
# 2    7.0
# 3    NaN
# 4    4.0
# 5    NaN
# dtype: float64>

# %%
filled=p.fillna(800)
filled
# Out:
# 0      3.0
# 1      5.0
# 2      7.0
# 3    800.0
# 4      4.0
# 5    800.0
# dtype: float64

# %%
p.dropna()
# Out:
# 0    3.0
# 1    5.0
# 2    7.0
# 4    4.0
# dtype: float64

# %%
p.iloc[1]
# Out:
# 5.0

# %%
p=pd.Series([10,20,30,40,50],index=['p','a','v','x','n'])
p
print(p.iloc[0])
print(p.iloc[1:4])
print(p.loc['a'])
print(p.loc['a':'n'])
# Out:
# 10
# a    20
# v    30
# x    40
# dtype: int64
# 20
# a    20
# v    30
# x    40
# n    50
# dtype: int64

# %%
p[p<30]
# Out:
# p    10
# a    20
# dtype: int64

# %%
p.sum()
# Out:
# 150

# %%
p.cumsum()
# Out:
# p     10
# a     30
# v     60
# x    100
# n    150
# dtype: int64

# %%
p.aggregate(['sum','mean','std'])
# Out:
# sum     150.000000
# mean     30.000000
# std      15.811388
# dtype: float64

# %%
data={
    'Name':['Lahari','Madhumika','Advitha'],
    'Rollno':['93','A0','C1'],
    'Blood Group':['O+','B+','O+'],
    'phone':['7777777777','9999999999','4444444444']
}
teamk = pd.DataFrame(data)

# %%
teamk.head()
# Out:
#         Name Rollno Blood Group       phone
# 0     Lahari     93          O+  7777777777
# 1  Madhumika     A0          B+  9999999999
# 2    Advitha     C1          O+  4444444444
